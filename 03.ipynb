# %%
from PIL import Image
from imgtools import *

# %%
my_path ='C:/Users/nk/Pictures/Meme/taj.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x412>

# %%
print(img.size)
# Out:
# (564, 412)

# %%
new_size = (600,600)
new_image =img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
thumbnail_size=(200,200)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x146>

# %%
#Chuyen sang xam
gray_image=img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=564x412>

# %%
#Phan RGB ra 3 tang mau khac nhau
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=564x412>
# <PIL.Image.Image image mode=L size=564x412>
# <PIL.Image.Image image mode=L size=564x412>

# %%
#Tron anh
merged_image=Image.merge("RGB",(red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=564x412>
